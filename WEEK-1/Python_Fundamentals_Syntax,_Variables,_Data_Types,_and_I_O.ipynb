# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ce-pixel/NASSCOM/blob/main/WEEK-1/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Python!")
if True:
    print("This code is indented correctly.")
else:
    print("This code won't run.")
# Out:
# Hello, Python!
# This code is indented correctly.

# %%
name = "Ashwitha"
age = 18
height = 6

# Print values
print("Name:", name)
print("Age:", age)
print("Height:", height)

# Variables are dynamically typed
name = 123  # Now 'name' holds an integer
print("New value of name:", name)
# Out:
# Name: Ashwitha
# Age: 18
# Height: 6
# New value of name: 123

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %%
b = 3.14
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Python"
print(type(c))

d = True
print(type(d))

e = [1, 2, 3, "four"]
print(type(e), e)

f = {"name": "Ashwitha", "age": 18}
print(type(f), f)
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'list'> [1, 2, 3, 'four']
# <class 'dict'> {'name': 'Ashwitha', 'age': 18}

# %%
print("Welcome to Python I/O!")
# Out:
# Welcome to Python I/O!

# %%
user_name = input("Enter your name: ")
print("Hello,", user_name)
# Out:
# Enter your name: Ashwitha
# Hello, Ashwitha

# %%
user_age = int(input("Enter your age: "))
print("You will be", user_age + 1, "next year.")
# Out:
# Enter your age: 18
# You will be 19 next year.
